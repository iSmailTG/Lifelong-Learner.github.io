# %%
from fastai.imports import *

# %%
df = pd.read_csv('train.csv')
df
# Out:
#                      id        anchor                  target context  score
# 0      37d61fd2272659b1     abatement  abatement of pollution     A47   0.50
# 1      7b9652b17b68b7a4     abatement          act of abating     A47   0.75
# 2      36d72442aefd8232     abatement         active catalyst     A47   0.25
# 3      5296b0c19e1ce60e     abatement     eliminating process     A47   0.50
# 4      54c1e3b9184cb5b6     abatement           forest region     A47   0.00
# ...                 ...           ...                     ...     ...    ...
# 36468  8e1386cbefd7f245  wood article          wooden article     B44   1.00
# 36469  42d9e032d1cd3242  wood article              wooden box     B44   0.50
# 36470  208654ccb9e14fa3  wood article           wooden handle     B44   0.50
# 36471  756ec035e694722b  wood article         wooden material     B44   0.75
# 36472  8d135da0b55b8c88  wood article        wooden substrate     B44   0.50
#
# [36473 rows x 5 columns]

# %%
df['section'] = df.context.str[0]
df.section
# Out:
# 0        A
# 1        A
# 2        A
# 3        A
# 4        A
#         ..
# 36468    B
# 36469    B
# 36470    B
# 36471    B
# 36472    B
# Name: section, Length: 36473, dtype: object

# %%
df[df.score==1]
# Out:
#                      id                anchor                     target  \
# 28     473137168ebf7484             abatement                    abating
# 158    621b048d70aa8867  absorbent properties  absorbent characteristics
# 161    bc20a1c961cb073a  absorbent properties      absorption properties
# 311    e955700dffd68624       acid absorption         absorption of acid
# 315    3a09aba546aac675       acid absorption            acid absorption
# ...                 ...                   ...                        ...
# 36398  913141526432f1d6         wiring trough             wiring troughs
# 36435  ee0746f2a8ecef97          wood article              wood articles
# 36440  ecaf479135cf0dfd          wood article             wooden article
# 36464  8ceaa2b5c2d56250          wood article               wood article
# 36468  8e1386cbefd7f245          wood article             wooden article
#
#       context  score section
# 28        F24    1.0       F
# 158       D01    1.0       D
# 161       D01    1.0       D
# 311       B08    1.0       B
# 315       B08    1.0       B
# ...       ...    ...     ...
# 36398     F16    1.0       F
# 36435     B05    1.0       B
# 36440     B05    1.0       B
# 36464     B44    1.0       B
# 36468     B44    1.0       B
#
# [1154 rows x 6 columns]

# %%
from torch.utils.data import DataLoader
import warnings,transformers,logging,torch
from transformers import TrainingArguments,Trainer
from transformers import AutoModelForSequenceClassification,AutoTokenizer
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In [19], line 2
#       1 from torch.utils.data import DataLoader
# ----> 2 import warnings,transformers,logging,torch
#       3 from transformers import TrainingArguments,Trainer
#       4 from transformers import AutoModelForSequenceClassification,AutoTokenizer
#
# File ~/mambaforge/lib/python3.10/site-packages/transformers/__init__.py:30
#      27 from typing import TYPE_CHECKING
#      29 # Check the dependencies satisfy the minimal versions required.
# ---> 30 from . import dependency_versions_check
#      31 from .utils import (
#      32     OptionalDependencyNotAvailable,
#      33     _LazyModule,
#    (...)
#      44     logging,
#      45 )
#      48 logger = logging.get_logger(__name__)  # pylint: disable=invalid-name
#
# File ~/mambaforge/lib/python3.10/site-packages/transformers/dependency_versions_check.py:41
#      38         if not is_tokenizers_available():
#      39             continue  # not required, check version only if installed
# ---> 41     require_version_core(deps[pkg])
#      42 else:
#      43     raise ValueError(f"can't find {pkg} in {deps.keys()}, check dependency_versions_table.py")
#
# File ~/mambaforge/lib/python3.10/site-packages/transformers/utils/versions.py:122, in require_version_core(requirement)
#     120 """require_version wrapper which emits a core-specific hint on failure"""
#     121 hint = "Try: pip install transformers -U or pip install -e '.[dev]' if you're working with git main"
# --> 122 return require_version(requirement, hint)
#
# File ~/mambaforge/lib/python3.10/site-packages/transformers/utils/versions.py:116, in require_version(requirement, hint)
#     114 if want_ver is not None:
#     115     for op, want_ver in wanted.items():
# --> 116         _compare_versions(op, got_ver, want_ver, requirement, pkg, hint)
#
# File ~/mambaforge/lib/python3.10/site-packages/transformers/utils/versions.py:49, in _compare_versions(op, got_ver, want_ver, requirement, pkg, hint)
#      47     raise ValueError("want_ver is None")
#      48 if not ops[op](version.parse(got_ver), version.parse(want_ver)):
# ---> 49     raise ImportError(
#      50         f"{requirement} is required for a normal functioning of this module, but found {pkg}=={got_ver}.{hint}"
#      51     )
#
# ImportError: tokenizers>=0.11.1,!=0.11.3,<0.13 is required for a normal functioning of this module, but found tokenizers==0.13.1.
# Try: pip install transformers -U or pip install -e '.[dev]' if you're working with git main
